# %%
import pandas as pd

wine = pd.read_csv('wine.csv')

data = wine[['alcohol', 'sugar', 'pH']]
target = wine['class']

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(data, target, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform, randint
import numpy as np

params = {'min_impurity_decrease' : uniform(0.0001, 0.001),
          'max_depth' : randint(20, 50),
          'min_samples_split' : randint(2, 25),
          'min_samples_leaf' : randint(1, 25),
          }

gs = RandomizedSearchCV(DecisionTreeClassifier(random_state=42), param_distributions=params, n_iter=100,  n_jobs=-1)
gs.fit(train_input, train_target)
print(gs.best_params_)
print(np.max(gs.cv_results_['mean_test_score']))
# Out:
# {'max_depth': 32, 'min_impurity_decrease': np.float64(0.0003643333083194349), 'min_samples_leaf': 4, 'min_samples_split': 4}
# 0.8687721181609536

# %%
dt = gs.best_estimator_
print(dt.score(test_input, test_target))
# Out:
# 0.8592307692307692
